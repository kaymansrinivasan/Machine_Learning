# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import chardet
from scipy.ndimage import label

df = pd.read_csv(r"C:\Users\User\PyCharmMiscProject\Datasets\circket.csv", encoding = "ISO-8859-1") #different read path ISO-8859-1 no utf-8\
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     int64
#  3   Inns    79 non-null     int64
#  4   NO      79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   HS      79 non-null     object
#  7   Ave     79 non-null     float64
#  8   BF      79 non-null     int64
#  9   SR      79 non-null     float64
#  10  100     79 non-null     int64
#  11  50      79 non-null     int64
#  12  0       79 non-null     int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 8.2+ KB

# %%
df
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3       ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4    DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
# ..                          ...        ...  ...   ...  ..    ...   ...    ...
# 74            CG Greenidge (WI)  1975-1991  128   127  13   5134  133*  45.03
# 75          Misbah-ul-Haq (PAK)  2002-2015  162   149  31   5122   96*  43.40
# 76         PD Collingwood (ENG)  2001-2011  197   181  37   5092  120*  35.36
# 77              A Symonds (AUS)  1998-2009  198   161  33   5088   156  39.75
# 78      Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080   112  29.70
#
#        BF     SR  100  50   0
# ...

# %%
df["HS"] = df["HS"].str.replace("*", "")

# %%
df["HS"] = df["HS"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     int64
#  3   Inns    79 non-null     int64
#  4   NO      79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   HS      79 non-null     int64
#  7   Ave     79 non-null     float64
#  8   BF      79 non-null     int64
#  9   SR      79 non-null     float64
#  10  100     79 non-null     int64
#  11  50      79 non-null     int64
#  12  0       79 non-null     int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 8.2+ KB

# %%
df[["start", "end"]] = df["Span"].str.split("-", expand=True)

# %%
df["start"] = df["start"].astype("int64")
df["end"] = df["end"].astype("int64")

# %%
df["exp"] = df["end"] - df["start"]

# %%
df.drop(columns=["start", "end", "Span", "Player"], inplace=True, axis=1)

# %%
df #no null, no duplicated
# Out:
#     Mat  Inns  NO   Runs   HS    Ave     BF     SR  100  50   0  exp
# 0   463   452  41  18426  200  44.83  21367  86.23   49  96  20   23
# 1   404   380  41  14234  169  41.98  18048  78.86   25  93  15   15
# 2   375   365  39  13704  164  42.03  17046  80.39   30  82  20   17
# 3   445   433  18  13430  189  32.36  14725  91.20   28  68  34   22
# 4   448   418  39  12650  144  33.37  16020  78.96   19  77  28   17
# ..  ...   ...  ..    ...  ...    ...    ...    ...  ...  ..  ..  ...
# 74  128   127  13   5134  133  45.03   7908  64.92   11  31   3   16
# 75  162   149  31   5122   96  43.40   6945  73.75    0  42   6   13
# 76  197   181  37   5092  120  35.36   6614  76.98    5  26   7   10
# 77  198   161  33   5088  156  39.75   5504  92.44    6  30  15   11
# 78  265   228  57   5080  112  29.70   6252  81.25    3  23  14   15
#
# [79 rows x 12 columns]

# %%
for col in df.columns:
    if df[col].dtypes != "object":
        sns.boxplot(df[col])
        plt.show()

# %%
df.columns
# Out:
# Index(['Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0',
#        'exp'],
#       dtype='object')

# %%
##features = df['Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0','exp']

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
scaled_data = sc.fit_transform(df)

df_scaler = pd.DataFrame(scaled_data)
df_scaler
# Out:
#           0         1         2         3         4         5         6   \
# 0   2.955282  3.169333  0.764963  4.262328  1.632443  1.072294  3.681214
# 1   2.155179  2.138915  0.764963  2.609117  0.635224  0.587725  2.635385
# 2   1.761908  1.924245  0.625397  2.400099  0.474382  0.596226  2.319651
# 3   2.711183  2.897417 -0.840046  2.292041  1.278591 -1.047909  1.588295
# 4   2.751866  2.682747  0.625397  1.984430 -0.168986 -0.876185  1.996354
# ..       ...       ...       ...       ...       ...       ...       ...
# 74 -1.587674 -1.481860 -1.188961 -0.979677 -0.522838  1.106299 -0.559768
# 75 -1.126598 -1.167010  0.067133 -0.984410 -1.713068  0.829159 -0.863213
# 76 -0.651961 -0.709047  0.485831 -0.996241 -0.941027 -0.537836 -0.967512
# 77 -0.638400 -0.995274  0.206699 -0.997819  0.217035  0.208570 -1.317278
# 78  0.270191 -0.036412  1.881490 -1.000973 -1.198374 -1.500174 -1.081580
#
#           7         8         9         10        11
# ...

# %%
df_scaler[3].mean()
# Out:
# np.float64(1.2648110407122037e-16)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=7)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=7)

# %%
df_scaler["basic_cluster"] = kmeans.labels_
df_scaler
# Out:
#            0         1         2         3         4         5         6  \
# 0   2.955282  3.169333  0.764963  4.262328  1.632443  1.072294  3.681214
# 1   2.155179  2.138915  0.764963  2.609117  0.635224  0.587725  2.635385
# 2   1.761908  1.924245  0.625397  2.400099  0.474382  0.596226  2.319651
# 3   2.711183  2.897417 -0.840046  2.292041  1.278591 -1.047909  1.588295
# 4   2.751866  2.682747  0.625397  1.984430 -0.168986 -0.876185  1.996354
# ..       ...       ...       ...       ...       ...       ...       ...
# 74 -1.587674 -1.481860 -1.188961 -0.979677 -0.522838  1.106299 -0.559768
# 75 -1.126598 -1.167010  0.067133 -0.984410 -1.713068  0.829159 -0.863213
# 76 -0.651961 -0.709047  0.485831 -0.996241 -0.941027 -0.537836 -0.967512
# 77 -0.638400 -0.995274  0.206699 -0.997819  0.217035  0.208570 -1.317278
# 78  0.270191 -0.036412  1.881490 -1.000973 -1.198374 -1.500174 -1.081580
#
#            7         8         9        10        11  basic_cluster
# ...

# %%
kmeans = KMeans(n_clusters=2, random_state=7)
kmeans.fit(df)


df_scaler["model2_clusters"] = kmeans.labels_
df_scaler

plt.scatter(df_scaler[3], df_scaler[5], c = df_scaler['model2_clusters'], cmap = 'viridis')
plt.xlabel("Runs")
plt.ylabel("Average")
plt.title("K-means clustering simplest model")
plt.show()

# %%
# !pip install plotly
# Out:
# ...
#   Using cached plotly-6.6.0-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached narwhals-2.18.0-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached plotly-6.6.0-py3-none-any.whl (9.9 MB)
# Using cached narwhals-2.18.0-py3-none-any.whl (444 kB)
# ...
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
# ...

# %%
inertia = []

for k in range(1,12):
    kmeans = KMeans(n_clusters=k, random_state=7)
    kmeans.fit(df)
    inertia.append(kmeans.inertia_)

plt.plot(range(1,12), inertia, marker='o', markerfacecolor='blue', linestyle='-', color='blue')
plt.title('Inertia for K-Means')
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %%
import plotly.express as px
fig = px.scatter_3d(df_scaler, x=3, y = 5, z=7, color='model2_clusters', title='K-means clustering simplest model')
fig.show()

# %%
"""from sklearn.metrics import silhouette_score
kmeans = KMeans(n_clusters=3, random_state=7, n_init=10)
labels = kmeans.fit_predict(df_scaler)

score = silhouette_score(df_scaler, labels)
print(score)"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 3
#       1 from sklearn.metrics import silhouette_score
#       2 kmeans = KMeans(n_clusters=3, random_state=7, n_init=10)
# ----> 3 labels = kmeans.fit_predict(df_scaler)
#       5 score = silhouette_score(df_scaler, labels)
#       6 print(score)
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1070, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1047 def fit_predict(self, X, y=None, sample_weight=None):
#    1048     """Compute cluster centers and predict cluster index for each sample.
#    1049
#    1050     Convenience method; equivalent to calling fit(X) followed by
#    (...)   1068         Index of the cluster each sample belongs to.
#    1069     """
# -> 1070     return self.fit(X, sample_weight=sample_weight).labels_
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib.pyplot import xlabel

# %%
df = pd.read_csv(r'C:\Users\User\PyCharmMiscProject\Datasets\new_insurance_data (1) - new_insurance_data (1).csv')
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
df.isna().sum()
df.dtypes
# Out:
# age                                float64
# sex                                 object
# bmi                                float64
# children                           float64
# smoker                              object
# Claim_Amount                       float64
# past_consultations                 float64
# num_of_steps                       float64
# Hospital_expenditure               float64
# NUmber_of_past_hospitalizations    float64
# Anual_Salary                       float64
# region                              object
# charges                            float64
# dtype: object

# %%
for col in df.columns:
  if df[col].dtype == "object":
    df[col] = df[col].fillna(df[col].mode([0]))
  else:
    df[col]=df[col].fillna(df[col].mean())

for col in df.columns:
  if df[col].dtype != "object":
    sb.boxplot(df[col])
    plt.xlabel(col)
    plt.show()

print(df.describe())
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.310008    30.665112     1.090773  33361.327180
# std      13.987500     6.094840     1.199606  15535.307255
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.315000     0.000000  20947.645198
# 50%      39.310008    30.400000     1.000000  33611.286065
# 75%      51.000000    34.656250     2.000000  44978.873188
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1338.000000  1.338000e+03          1.338000e+03
# mean            15.216216  9.100047e+05          1.584179e+07
# std              7.450948  9.178297e+04          2.665309e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.474898e+05          4.084941e+06
# ...

# %%
#log transformation
df["log_hospital_exp"] = np.log(df["Hospital_expenditure"])
df["log_Anual_salary"] = np.log(df["Anual_Salary"])
df["log_charges"] = np.log(df["charges"])
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
"""outlist=['bmi','past_consultations','Hospital_expenditure','Anual_Salary']

for col in outlist:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)

    iqr = q3 - q1

    lb = q1 - 1.5 * iqr
    ub = q3 + 1.5 * iqr

    df=df[(df[col]>= lb) & (df[col]<=ub)]"""
# Out:
# "outlist=['bmi','past_consultations','Hospital_expenditure','Anual_Salary']\n\nfor col in outlist:\n    q1 = df[col].quantile(0.25)\n    q3 = df[col].quantile(0.75)\n\n    iqr = q3 - q1\n\n    lb = q1 - 1.5 * iqr\n    ub = q3 + 1.5 * iqr\n\n    df=df[(df[col]>= lb) & (df[col]<=ub)]"

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.columns:
    if df[col].dtypes == "object":
        df[col]= le.fit_transform(df[col])
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges',
#        'log_hospital_exp', 'log_Anual_salary', 'log_charges'],
#       dtype='object')

# %%
X = df.drop(['charges', 'log_charges'], axis=1)
Y = df['charges']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.80, random_state=0)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
ypred = model.predict(x_test)
result = pd.DataFrame(columns=["actual", "predicted"])
result["actual"] = y_test
result["predicted"] = ypred
result
# Out:
#            actual     predicted
# 578    8116.26885   9813.347291
# 610    8534.67180   9929.144748
# 569    7986.47525   9067.410377
# 1034  18648.42170  19383.688891
# 198    3161.45400   2530.609639
# ...           ...           ...
# 1084  21223.67580  21860.263227
# 726   10231.49990  10667.053466
# 1132  24671.66334  21901.262903
# 725   10226.28420  11295.065306
# 963   14382.70905  13495.898221
#
# [268 rows x 2 columns]

# %%
from sklearn.metrics import *
r_2 = r2_score(y_test, ypred)
r_2*100
# Out:
# 98.77850170790322

# %%
sb.regplot(x = y_test, y = ypred, color = "#00FFFF")
plt.title(f"Regression Result = {r_2*100}")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
